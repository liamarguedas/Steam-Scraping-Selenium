# %%
import pandas as pd

# %%
data = pd.read_csv('games.csv', index_col = 0)
data
# Out:
#                                 Game AgeRestriction  \
# 0   Counter-Strike: Global Offensive             No
# 1                 EA SPORTS™ FIFA 23             No
# 2                PUBG: BATTLEGROUNDS             No
# 3                    Resident Evil 4            Yes
# 4  Call of Duty®: Modern Warfare® II            Yes
# 5                      Path of Exile             No
# 6                 Grand Theft Auto V             No
# 7                         GrandChase            Yes
# 8                        Bloons TD 6             No
# 9                       No Man's Sky             No
#
#                                      GameDescription  \
# 0  O Counter-Strike: Global Offensive (CS:GO) mel...
# 1  FIFA 23 traz o Jogo de Todo Mundo aos gramados...
# 2  Jogue PUBG: BATTLEGROUNDS de graça. Pouse em l...
# 3  Sobrevivência é apenas o começo. Seis anos se ...
# 4  O Call of Duty®: Modern Warfare® II coloca os ...
# 5  You are an Exile, struggling to survive on the...
# ...
