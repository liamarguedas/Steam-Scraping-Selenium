# %%
import pandas as pd

# %%
data = pd.read_csv('games.csv', index_col = 0)
data
# Out:
#                                 Game AgeRestriction  \
# 0   Counter-Strike: Global Offensive             No
# 1                 EA SPORTS™ FIFA 23             No
# 2                    Resident Evil 4            Yes
# 3                      Path of Exile             No
# 4                        Bloons TD 6             No
# 5                 Grand Theft Auto V             No
# 6  Call of Duty®: Modern Warfare® II            Yes
# 7                           V Rising             No
# 8                          Destiny 2             No
#
#                                      GameDescription  \
# 0  O Counter-Strike: Global Offensive (CS:GO) mel...
# 1  FIFA 23 traz o Jogo de Todo Mundo aos gramados...
# 2  Sobrevivência é apenas o começo. Seis anos se ...
# 3  You are an Exile, struggling to survive on the...
# 4                  Incrível Jogo de Defesa de Torres
# 5  Grand Theft Auto V para PC oferece aos jogador...
# 6  O Call of Duty®: Modern Warfare® II coloca os ...
# ...
