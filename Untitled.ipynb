# %%
import pandas as pd

# %%
data = pd.read_csv('games.csv')
data
# Out:
#    Unnamed: 0                               Game AgeRestriction  \
# 0           0   Counter-Strike: Global Offensive             No
# 1           1                 EA SPORTS™ FIFA 23             No
# 2           2                    Resident Evil 4            Yes
# 3           3                      Path of Exile             No
# 4           4                 Grand Theft Auto V             No
# 5           5                        Bloons TD 6             No
# 6           6  Call of Duty®: Modern Warfare® II            Yes
# 7           7                           V Rising             No
# 8           8                          Destiny 2             No
#
#                                      GameDescription  \
# 0  O Counter-Strike: Global Offensive (CS:GO) mel...
# 1  FIFA 23 traz o Jogo de Todo Mundo aos gramados...
# 2  Sobrevivência é apenas o começo. Seis anos se ...
# 3  You are an Exile, struggling to survive on the...
# 4  Grand Theft Auto V para PC oferece aos jogador...
# ...

# %%
data['PEGI'][0]
# Out:
# 'https://store.cloudflare.steamstatic.com/public/shared/images/game_ratings/DEJUS/16.png'

# %%
'TÍTULO: Counter-Strike: Global Offensive\nGÊNERO: Ação, Gratuito p/ Jogar\nDESENVOLVEDOR: Valve, Hidden Path Entertainment\nDISTRIBUIDORA: Valve\nDATA DE LANÇAMENTO: 21/ago./2012'.split(':')[3].split()[0]
# Out:
# 'Ação,'
