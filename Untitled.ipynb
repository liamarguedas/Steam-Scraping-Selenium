# %%
import pandas as pd

# %%
pd.read_csv('games.csv')
# Out:
#    Unnamed: 0                              Game  AgeRestriction  \
# 0           0  Counter-Strike: Global Offensive               0
# 1           1                EA SPORTS™ FIFA 23               0
# 2           2                   Resident Evil 4               1
# 3           3                     Path of Exile               0
# 4           4                Grand Theft Auto V               0
# 5           5            Euro Truck Simulator 2               0
# 6           6                         Destiny 2               0
# 7           7                          V Rising               0
# 8           8                       Ravenswatch               1
#
#                                      GameDescription  Reviews  \
# 0  O Counter-Strike: Global Offensive (CS:GO) mel...      NaN
# 1  FIFA 23 traz o Jogo de Todo Mundo aos gramados...      NaN
# 2  Sobrevivência é apenas o começo. Seis anos se ...      NaN
# 3  You are an Exile, struggling to survive on the...      NaN
# ...
